# %% [markdown]
# **IMPORT LIBRARYIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats
import re
import seaborn as sns
print('seaborn versiont:',sns.__version__)
import os
import warnings
warnings.filterwarnings('ignore')
# Out:
# seaborn versiont: 0.11.2

# %% [markdown]
# **Import Data set**

# %%
df=pd.read_excel("/content/Sales_Data.xlsx")

# %% [markdown]
# Head 5 customer list

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  ...  CONTACTFIRSTNAME  DEALSIZE
# 0        10107               30  ...              Kwai     Small
# 1        10121               34  ...              Paul     Small
# 2        10134               41  ...            Daniel    Medium
# 3        10145               45  ...             Julie    Medium
# 4        10168               36  ...              Juri    Medium
#
# [5 rows x 20 columns]

# %%
df.tail()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  ...  CONTACTFIRSTNAME  DEALSIZE
# 2742        10350               20  ...             Diego     Small
# 2743        10373               29  ...            Pirkko    Medium
# 2744        10386               43  ...             Diego    Medium
# 2745        10397               34  ...           Annette     Small
# 2746        10414               47  ...              Juri    Medium
#
# [5 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747 entries, 0 to 2746
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORDERNUMBER           2747 non-null   int64
#  1   QUANTITYORDERED       2747 non-null   int64
#  2   PRICEEACH             2747 non-null   float64
#  3   ORDERLINENUMBER       2747 non-null   int64
#  4   SALES                 2747 non-null   float64
#  5   ORDERDATE             2747 non-null   datetime64[ns]
#  6   DAYS_SINCE_LASTORDER  2747 non-null   int64
#  7   STATUS                2747 non-null   object
#  8   PRODUCTLINE           2747 non-null   object
#  9   MSRP                  2747 non-null   int64
#  10  PRODUCTCODE           2747 non-null   object
#  11  CUSTOMERNAME          2747 non-null   object
#  12  PHONE                 2747 non-null   object
#  13  ADDRESSLINE1          2747 non-null   object
#  14  CITY                  2747 non-null   object
# ...

# %%
df.dtypes
# Out:
# ORDERNUMBER                      int64
# QUANTITYORDERED                  int64
# PRICEEACH                      float64
# ORDERLINENUMBER                  int64
# SALES                          float64
# ORDERDATE               datetime64[ns]
# DAYS_SINCE_LASTORDER             int64
# STATUS                          object
# PRODUCTLINE                     object
# MSRP                             int64
# PRODUCTCODE                     object
# CUSTOMERNAME                    object
# PHONE                           object
# ADDRESSLINE1                    object
# CITY                            object
# POSTALCODE                      object
# COUNTRY                         object
# CONTACTLASTNAME                 object
# CONTACTFIRSTNAME                object
# DEALSIZE                        object
# dtype: object

# %% [markdown]
# Here we are observe that there one data type is based on date time witch is show us a date and time of order

# %%
df.shape
# Out:
# (2747, 20)

# %% [markdown]
# in this data set there is 2747 raws and 20 calumns

# %%
df.describe().T
# Out:
#                        count          mean  ...        75%       max
# ORDERNUMBER           2747.0  10259.761558  ...  10334.500  10425.00
# QUANTITYORDERED       2747.0     35.103021  ...     43.000     97.00
# PRICEEACH             2747.0    101.098951  ...    127.100    252.87
# ORDERLINENUMBER       2747.0      6.491081  ...      9.000     18.00
# SALES                 2747.0   3553.047583  ...   4503.095  14082.80
# DAYS_SINCE_LASTORDER  2747.0   1757.085912  ...   2436.500   3562.00
# MSRP                  2747.0    100.691664  ...    124.000    214.00
#
# [7 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER             0
# QUANTITYORDERED         0
# PRICEEACH               0
# ORDERLINENUMBER         0
# SALES                   0
# ORDERDATE               0
# DAYS_SINCE_LASTORDER    0
# STATUS                  0
# PRODUCTLINE             0
# MSRP                    0
# PRODUCTCODE             0
# CUSTOMERNAME            0
# PHONE                   0
# ADDRESSLINE1            0
# CITY                    0
# POSTALCODE              0
# COUNTRY                 0
# CONTACTLASTNAME         0
# CONTACTFIRSTNAME        0
# DEALSIZE                0
# dtype: int64

# %% [markdown]
# Here we are observe that there is no null or empt values are there

# %% [markdown]
# **EDA**

# %% [markdown]
# Univariate

# %%
fig, (ax1,ax2,ax3)=plt.subplots(1,3,figsize=(13,5))

#boxplot
sns.boxplot(x='QUANTITYORDERED',data=df,orient='v',ax=ax1)
ax1.set_ylabel('QUANTITYORDERED', fontsize=15)
ax1.set_title('QUANTITYORDERED', fontsize=15)
ax1.tick_params(labelsize=15)

#distplot
sns.distplot(df['QUANTITYORDERED'],ax=ax2)
ax2.set_xlabel('QUANTITYORDERED', fontsize=15)
ax2.tick_params(labelsize=15)

#histogram
ax3.hist(df['QUANTITYORDERED'])
ax3.set_xlabel('QUANTITYORDERED', fontsize=15)
ax3.tick_params(labelsize=15)

plt.subplots_adjust(wspace=0.5)
plt.tight_layout()

# %% [markdown]
# Here is some outlayers are there

# %%
fig, (ax1,ax2,ax3)=plt.subplots(1,3,figsize=(13,5))

#boxplot
sns.boxplot(x='PRICEEACH',data=df,orient='v',ax=ax1)
ax1.set_ylabel('PRICEEACH', fontsize=15)
ax1.set_title('PRICEEACH', fontsize=15)
ax1.tick_params(labelsize=15)

#distplot
sns.distplot(df['PRICEEACH'],ax=ax2)
ax2.set_xlabel('PRICEEACH', fontsize=15)
ax2.tick_params(labelsize=15)

#histogram
ax3.hist(df['PRICEEACH'])
ax3.set_xlabel('PRICEEACH', fontsize=15)
ax3.tick_params(labelsize=15)

plt.subplots_adjust(wspace=0.5)
plt.tight_layout()

# %%
fig, (ax1,ax2,ax3)=plt.subplots(1,3,figsize=(13,5))

#boxplot
sns.boxplot(x='ORDERNUMBER',data=df,orient='v',ax=ax1)
ax1.set_ylabel('ORDERNUMBER', fontsize=15)
ax1.set_title('ORDERNUMBER', fontsize=15)
ax1.tick_params(labelsize=15)

#distplot
sns.distplot(df['ORDERNUMBER'],ax=ax2)
ax2.set_xlabel('ORDERNUMBER', fontsize=15)
ax2.tick_params(labelsize=15)

#histogram
ax3.hist(df['ORDERNUMBER'])
ax3.set_xlabel('ORDERNUMBER', fontsize=15)
ax3.tick_params(labelsize=15)

plt.subplots_adjust(wspace=0.5)
plt.tight_layout()

# %%
fig, (ax1,ax2,ax3)=plt.subplots(1,3,figsize=(13,5))

#boxplot
sns.boxplot(x='SALES',data=df,orient='v',ax=ax1)
ax1.set_ylabel('SALES', fontsize=15)
ax1.set_title('SALES', fontsize=15)
ax1.tick_params(labelsize=15)

#distplot
sns.distplot(df['SALES'],ax=ax2)
ax2.set_xlabel('SALES', fontsize=15)
ax2.tick_params(labelsize=15)

#histogram
ax3.hist(df['SALES'])
ax3.set_xlabel('SALES', fontsize=15)
ax3.tick_params(labelsize=15)

plt.subplots_adjust(wspace=0.5)
plt.tight_layout()

# %%
fig, (ax1,ax2,ax3)=plt.subplots(1,3,figsize=(13,5))

#boxplot
sns.boxplot(x='MSRP',data=df,orient='v',ax=ax1)
ax1.set_ylabel('MSRP', fontsize=15)
ax1.set_title('MSRP', fontsize=15)
ax1.tick_params(labelsize=15)

#distplot
sns.distplot(df['MSRP'],ax=ax2)
ax2.set_xlabel('MSRP', fontsize=15)
ax2.tick_params(labelsize=15)

#histogram
ax3.hist(df['MSRP'])
ax3.set_xlabel('MSRP', fontsize=15)
ax3.tick_params(labelsize=15)

plt.subplots_adjust(wspace=0.5)
plt.tight_layout()

# %%
df.hist(figsize=(12,16),layout=(4,2));

# %% [markdown]
# Multyvariate

# %%
sns.pairplot(df);

# %%
df.corr().T
# Out:
#                       ORDERNUMBER  ...      MSRP
# ORDERNUMBER              1.000000  ... -0.013910
# QUANTITYORDERED          0.067110  ...  0.020551
# PRICEEACH               -0.003369  ...  0.778393
# ORDERLINENUMBER         -0.054300  ... -0.020956
# SALES                    0.037289  ...  0.634849
# DAYS_SINCE_LASTORDER    -0.251476  ... -0.524285
# MSRP                    -0.013910  ...  1.000000
#
# [7 rows x 7 columns]

# %% [markdown]
# here we are observe that there are so maney nagative corilation betweeen columns

# %%
#creating a heatmap for better visualization
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True,fmt=".2f",cmap="jet_r")
plt.show()

# %%
c = df.corr().abs() # Since there may be positive as well as -ve correlation
s = c.unstack() # 
so = s.sort_values(ascending=False) # Sorting according to the correlation
so=so[(so<1) & (so>0.3)].drop_duplicates().to_frame() # Due to symmetry.. dropping duplicate entries.
so.columns = ['correlation']
so
# Out:
#                                            correlation
# PRICEEACH            SALES                    0.808287
# MSRP                 PRICEEACH                0.778393
#                      SALES                    0.634849
# QUANTITYORDERED      SALES                    0.553359
# MSRP                 DAYS_SINCE_LASTORDER     0.524285
# DAYS_SINCE_LASTORDER PRICEEACH                0.397092
# SALES                DAYS_SINCE_LASTORDER     0.334274

# %% [markdown]
# By using this method we are droping nagative values and now we can observe a perfect co relation chart

# %%
df.COUNTRY.value_counts()[:10].plot(kind='bar')

# %% [markdown]
# In the given dataset, you can observe most of the customers are from the "USA".

# %%
us_data = df[df.COUNTRY=='USA']
us_data.head()
# Out:
#     ORDERNUMBER  QUANTITYORDERED  ...  CONTACTFIRSTNAME  DEALSIZE
# 0         10107               30  ...              Kwai     Small
# 3         10145               45  ...             Julie    Medium
# 4         10168               36  ...              Juri    Medium
# 9         10237               23  ...           Michael     Small
# 10        10251               28  ...           William    Medium
#
# [5 rows x 20 columns]

# %%
us_data.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED  ...  DAYS_SINCE_LASTORDER        MSRP
# count    928.000000       928.000000  ...            928.000000  928.000000
# mean   10259.209052        35.581897  ...           1737.018319  101.098060
# std       88.035784         9.899701  ...            814.867748   40.515983
# min    10100.000000         6.000000  ...            111.000000   33.000000
# 25%    10183.000000        27.000000  ...           1050.000000   68.000000
# 50%    10264.000000        36.000000  ...           1753.000000   99.000000
# 75%    10324.000000        44.000000  ...           2420.500000  124.000000
# max    10422.000000        85.000000  ...           3413.000000  214.000000
#
# [8 rows x 7 columns]

# %% [markdown]
# Here, you can observe there is no nagative values are there so we are working on it withaout any major change

# %%
n_df=df[['ORDERNUMBER','CUSTOMERNAME','DAYS_SINCE_LASTORDER','QUANTITYORDERED','SALES']]

# %% [markdown]
# ### Filter required Columns
# Here, you can filter the necessary columns for RFM analysis. You only need her five columns ORDERNUMBER, CUSTOMERNAME, DAYS SINCE LASTORDER, QUANTITYORDER, and and SALES. Customer name will uniquely define your customers, Order number help you calculate recency of purchase, Quantity of order helps you to count the number of time transaction performed(frequency). Quantity purchased in each transaction and Sales of each unit purchased by the customer will help you to calculate the total purchased amount.

# %%
n_df.head()
# Out:
#    ORDERNUMBER          CUSTOMERNAME  ...  QUANTITYORDERED    SALES
# 0        10107     Land of Toys Inc.  ...               30  2871.00
# 1        10121    Reims Collectables  ...               34  2765.90
# 2        10134       Lyon Souveniers  ...               41  3884.34
# 3        10145     Toys4GrownUps.com  ...               45  3746.70
# 4        10168  Technics Stores Inc.  ...               36  3479.76
#
# [5 rows x 5 columns]

# %%
n_df.columns
# Out:
# Index(['ORDERNUMBER', 'CUSTOMERNAME', 'DAYS_SINCE_LASTORDER',
#        'QUANTITYORDERED', 'SALES'],
#       dtype='object')

# %% [markdown]
# ### RFM Analysis
# Here, you are going to perform following opertaions:
#
# For Recency, Calculate the number of days between present date and date of last purchase each customer.
# For Frequency, Calculate the number of orders for each customer.
# For Monetary, Calculate sum of purchase price for each customer.

# %%
rfm=n_df
rfm=n_df.rename(columns = {'DAYS_SINCE_LASTORDER': 'recency', 'QUANTITYORDERED': 'frequency','SALES':'monetary'}, inplace = False)

# %%
rfm.head()
# Out:
#    ORDERNUMBER          CUSTOMERNAME  recency  frequency  monetary
# 0        10107     Land of Toys Inc.      828         30   2871.00
# 1        10121    Reims Collectables      757         34   2765.90
# 2        10134       Lyon Souveniers      703         41   3884.34
# 3        10145     Toys4GrownUps.com      649         45   3746.70
# 4        10168  Technics Stores Inc.      586         36   3479.76

# %% [markdown]
# ### Computing Quantile of RFM values
# Customers with the lowest recency, highest frequency and monetary amounts considered as top customers.
#
# qcut() is Quantile-based discretization function. qcut bins the data based on sample quantiles. For example, 1000 values for 4 quantiles would produce a categorical object indicating quantile membership for each customer.

# %%
rfm['r_quartile'] = pd.qcut(rfm['recency'], 4, ['1','2','3','4'])
rfm['f_quartile'] = pd.qcut(rfm['frequency'], 4, ['4','3','2','1'])
rfm['m_quartile'] = pd.qcut(rfm['monetary'], 4, ['4','3','2','1'])

# %% [markdown]
# ### RFM Result Interpretation
# Combine all three quartiles(r_quartile,f_quartile,m_quartile) in a single column, this rank will help you to segment the customers well group.

# %%
rfm.head(10)
# Out:
#    ORDERNUMBER                CUSTOMERNAME  ...  f_quartile  m_quartile
# 0        10107           Land of Toys Inc.  ...           3           3
# 1        10121          Reims Collectables  ...           3           3
# 2        10134             Lyon Souveniers  ...           2           2
# 3        10145           Toys4GrownUps.com  ...           1           2
# 4        10168        Technics Stores Inc.  ...           2           2
# 5        10180    Daedalus Designs Imports  ...           3           3
# 6        10188                Herkku Gifts  ...           1           1
# 7        10211            Auto Canal Petit  ...           2           1
# 8        10223  Australian Collectors, Co.  ...           2           2
# 9        10237             Vitachrome Inc.  ...           4           3
#
# [10 rows x 8 columns]

# %%
rfm['RFM_Score'] = rfm.r_quartile.astype(str)+ rfm.f_quartile.astype(str) + rfm.m_quartile.astype(str)
rfm.head(10)
# Out:
#    ORDERNUMBER                CUSTOMERNAME  ...  m_quartile  RFM_Score
# 0        10107           Land of Toys Inc.  ...           3        133
# 1        10121          Reims Collectables  ...           3        133
# 2        10134             Lyon Souveniers  ...           2        122
# 3        10145           Toys4GrownUps.com  ...           2        112
# 4        10168        Technics Stores Inc.  ...           2        122
# 5        10180    Daedalus Designs Imports  ...           3        133
# 6        10188                Herkku Gifts  ...           1        111
# 7        10211            Auto Canal Petit  ...           1        121
# 8        10223  Australian Collectors, Co.  ...           2        122
# 9        10237             Vitachrome Inc.  ...           3        143
#
# [10 rows x 9 columns]

# %%
# Filter out Top/Best cusotmers
rfm[rfm['RFM_Score']=='111'].sort_values('monetary', ascending=False).head(10)
# Out:
#       ORDERNUMBER                  CUSTOMERNAME  ...  m_quartile  RFM_Score
# 571         10407     The Sharp Gifts Warehouse  ...           1        111
# 714         10322  Online Diecast Creations Co.  ...           1        111
# 49          10424         Euro Shopping Channel  ...           1        111
# 1020        10412         Euro Shopping Channel  ...           1        111
# 96          10403         UK Collectables, Ltd.  ...           1        111
# 42          10312  Mini Gifts Distributors Ltd.  ...           1        111
# 176         10127            Muscle Machine Inc  ...           1        111
# 28          10150       Dragon Souveniers, Ltd.  ...           1        111
# 186         10247           Suominen Souveniers  ...           1        111
# 41          10304            Auto Assoc. & Cie.  ...           1        111
#
# [10 rows x 9 columns]

# %%
# Filter out lost cusotmers
rfm[rfm['RFM_Score']=='333'].sort_values('monetary', ascending=False).tail(10)
# Out:
#       ORDERNUMBER                        CUSTOMERNAME  ...  m_quartile  RFM_Score
# 1797        10288                    Handji Gifts& Co  ...           3        333
# 1790        10192        Online Diecast Creations Co.  ...           3        333
# 2197        10314                Heintze Collectables  ...           3        333
# 1636        10124                  Signal Gift Stores  ...           3        333
# 1947        10296  Bavarian Collectables Imports, Co.  ...           3        333
# 1786        10148             Anna's Decorations, Ltd  ...           3        333
# 1854        10386               Euro Shopping Channel  ...           3        333
# 1699        10284           Norway Gifts By Mail, Co.  ...           3        333
# 2029        10423                          Petit Auto  ...           3        333
# 1814        10203               Euro Shopping Channel  ...           3        333
#
# [10 rows x 9 columns]

# %% [markdown]
# Conclusion
#
# In this tutorial, covered a lot of details about Customer Segmentation. I have learned what the customer segmentation is, Need of Customer Segmentation, Types of Segmentation, RFM analysis, Implementation of RFM from scratch in python. Also, covered some basic concepts of pandas such as handling duplicates, groupby, and qcut() for bins based on sample quantiles.

# %% [markdown]
# #### **PGP DSBA FEB_A 2021**
# #### **HARSH ALKESH PANDYA**
# #### **RFM MILESTONE 1**
